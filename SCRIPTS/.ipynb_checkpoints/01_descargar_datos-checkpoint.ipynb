# %% [markdown]
# # Notebook de descarga de información

# %% [markdown]
# ## Información de datos abiertos
#
# ### `Explicación breve del conjunto de datos "Copiar lo que dice el conjunto de datos"`

# %% [markdown]
# ## Importar librerias

# %%
# librerias base
import math
import os
import shutil 
import sys

#librerias externas
import pandas
import numpy

# librerias propias
# Carpeta del proyecto
dir_proyecto, _ = os.path.split(os.getcwd())
sys.path.append(dir_proyecto)
from SCRIPTS.funciones import *

# %% [markdown]
# ## Descargar información

# %%
# Carpetas del proyecto

try:
    os.mkdir(os.path.join(dir_proyecto,'INPUTS'))
except:
    None

try:
    shutil.rmtree(os.path.join(dir_proyecto,'INPUTS'))
except:
    None
os.mkdir(os.path.join(dir_proyecto,'INPUTS'))

# %%
# parámetros de las funciones
id_conjunto = 'jbjy-vk9h'
limit = 5000
ordenar = "id_contrato"
# filtro sobre el conjunto. Año 2023 cuyo valor sea superior a cien millones de pesos
where = "fecha_de_firma>='2023-01-01T00:00:00.000' and valor_del_contrato >= 100000000"

# %%
tamanio_conjunto = dimensionar_conjunto(id_conjunto, where=where)
tamanio_conjunto
# Out:
# 39884

# %%
loops = math.ceil(tamanio_conjunto/limit)

for offset in range (loops):
    consultar_conjunto_paginado(id_conjunto, limit, ordenar, offset, where = where)

# %% [markdown]
# ## Probar la lectura de los datos

# %%
contratacion = leer_parquet(os.path.join(dir_proyecto,'INPUTS'))
contratacion
# Out:
#                                   nombre_entidad nit_entidad  \
# 0                             MUNICIPIO DE TUNJA   891800846
# 1                    ALCALDIA DE FLORENCIA CAUCA   800188492
# 2     AGENCIA LOGISTICA DE LAS FUERZAS MILITARES   899999162
# 3         INSTITUTO DE VALORIZACION DE MANIZALES   800002916
# 4                                            HMI   802013023
# ...                                          ...         ...
# 4995          UNIDADES TECNOLOGICAS DE SANTANDER   890208727
# 4996       EMPRESA DE ENERGÍA DE CASANARE SA ESP   844004576
# 4997                         ICBF REGIONAL CAUCA   899999239
# 4998                       MUNICIPIO DE MONTERIA   800096734
# 4999                        MUNICIPIO DE SOLEDAD   890106291
#
#                     departamento       ciudad  \
# 0                         Boyacá        Tunja
# 1                          Cauca    Florencia
# 2     Distrito Capital de Bogotá       Bogotá
# 3                         Caldas    Manizales
# 4                      Atlántico      Soledad
# ...                          ...          ...
# 4995                   Santander  Bucaramanga
# 4996                    Casanare        Yopal
# 4997                       Cauca      Popayán
# 4998                     Córdoba     Montería
# 4999                   Atlántico      Soledad
#
#                              localizaci_n        orden  \
# 0              Colombia,  Boyacá ,  Tunja  Territorial
# 1           Colombia,  Cauca ,  Florencia  Territorial
# 2                Colombia, Bogotá, Bogotá     Nacional
# 3          Colombia,  Caldas ,  Manizales  Territorial
# 4         Colombia,  Atlántico ,  Soledad  Territorial
# ...                                   ...          ...
# 4995  Colombia,  Santander ,  Bucaramanga  Territorial
# 4996         Colombia,  Casanare ,  Yopal  Territorial
# 4997          Colombia,  Cauca ,  Popayán     Nacional
# 4998       Colombia,  Córdoba ,  Montería  Territorial
# 4999      Colombia,  Atlántico ,  Soledad  Territorial
#
#                          sector                  rama entidad_centralizada  \
# 0              Servicio Público             Ejecutivo      Descentralizada
# 1        No aplica/No pertenece             Ejecutivo      Descentralizada
# 2                       defensa             Ejecutivo      Descentralizada
# 3               Minas y Energía             Ejecutivo      Descentralizada
# 4     Salud y Protección Social  Corporación Autónoma      Descentralizada
# ...                         ...                   ...                  ...
# 4995     No aplica/No pertenece  Corporación Autónoma      Descentralizada
# 4996            Minas y Energía  Corporación Autónoma      Descentralizada
# 4997  Salud y Protección Social             Ejecutivo         Centralizada
# 4998           Servicio Público             Ejecutivo      Descentralizada
# 4999           Servicio Público             Ejecutivo      Descentralizada
#
#      proceso_de_compra  ... recursos_de_credito recursos_propios  \
# 0     CO1.BDOS.3881955  ...                   0                0
# 1     CO1.BDOS.4146649  ...          1360000000                0
# 2     CO1.BDOS.3960837  ...                   0                0
# 3     CO1.BDOS.3903416  ...                   0                0
# 4     CO1.BDOS.4147415  ...                   0                0
# ...                ...  ...                 ...              ...
# 4995  CO1.BDOS.3954080  ...                   0        183624120
# 4996  CO1.BDOS.3945433  ...                   0                0
# 4997  CO1.BDOS.3954768  ...                   0                0
# 4998  CO1.BDOS.3954465  ...                   0                0
# 4999  CO1.BDOS.3949987  ...                   0                0
#
#          ultima_actualizacion codigo_entidad codigo_proveedor  \
# 0     2023-07-25T00:00:00.000      702354804        705396323
# 1     2023-03-13T00:00:00.000      702224064        704040070
# 2     2023-08-19T00:00:00.000      700985252        710330192
# 3     2023-05-23T00:00:00.000      713090454        701957052
# 4     2023-03-25T00:00:00.000      703176586        718568512
# ...                       ...            ...              ...
# 4995  2023-02-21T00:00:00.000      704329291        702423013
# 4996  2023-08-03T00:00:00.000      718458664        714148442
# 4997  2023-08-22T00:00:00.000      704198639        706275120
# 4998  2023-03-06T00:00:00.000      702923731        710851858
# 4999  2023-07-21T00:00:00.000      702266156        716893813
#
#                                     objeto_del_contrato  \
# 0     SMA034 RESTAURACIÓN DE LA COBERTURA VEGETAL EN...
# 1     CONTRATO DE EMPRÉSTITO Y PIGNORACIÓN DE RENTAS...
# 2     SUMINISTRO DE CARNE DE RES Y CERDO SIN ADITIVO...
# 3     PRESTAR EL SERVICIO DE VIGILANCIA Y SEGURIDAD ...
# 4     PRESTACIÓN DE SERVICIOS PROFESIONALES PARA DEF...
# ...                                                 ...
# 4995  CONTRATACIÓN DE SERVICIOS PROFESIONALES ESPECI...
# 4996  SERVICIO DE TRANSPORTE TERRESTRE DE PERSONAL I...
# 4997  PRESTAR LOS SERVICIOS DE EDUCACIÓN INICIAL EN ...
# 4998  PRESTACIÓN DE SERVICIOS PROFESIONALES Y ESPECI...
# 4999  PRESTACION DE SERVICIIOS DE APOYO A LA GESTION...
#
#      fecha_inicio_liquidacion fecha_fin_liquidacion  \
# 0                        None                  None
# 1                        None                  None
# 2         2023-05-01 13:00:00   2023-10-01 04:59:00
# 3         2024-01-02 13:00:00   2024-05-02 16:59:00
# 4         2023-06-01 13:00:00   2023-10-01 04:59:00
# ...                       ...                   ...
# 4995      2023-12-09 17:00:00   2024-04-09 17:00:00
# 4996      2023-05-21 17:00:00   2023-09-21 04:59:00
# 4997                     None                  None
# 4998                     None                  None
# 4999      2023-12-15 17:00:00   2024-04-08 17:00:00
#
#      fecha_de_inicio_de_ejecucion fecha_de_fin_de_ejecucion
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 4995                         None                      None
# 4996                         None                      None
# 4997                         None                      None
# 4998                         None                      None
# 4999                         None                      None
#
# [39884 rows x 71 columns]
